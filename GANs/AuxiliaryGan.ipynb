# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import os
os.chdir("/content/drive/My Drive/Colab Notebooks/GAN")

# %%
# Imports
from keras.optimizers import RMSprop
from keras.datasets import mnist
from keras.layers import Dense, Reshape, Conv2DTranspose, BatchNormalization
from keras.layers import Activation, LeakyReLU, Conv2D, Flatten, Input, concatenate
from keras.models import Model
from keras.utils import to_categorical
import numpy as np
from matplotlib import pyplot as plt
import os
# Out:
# Using TensorFlow backend.

# %%
'''Dynamic and Hyper parameters'''
latent_dim = 100
image_size = 28
image_shape = (image_size, image_size, 1)

gen_filters = [128, 64, 32, 1]
gen_strides = [2, 2, 1, 1]

dis_filters = [32, 64, 128, 256]
dis_strides = [2, 2, 2, 1]

kernel_size = (5, 5)
alpha = 0.2

dis_lr = 2e-4
dis_decay = 6e-8
dis_opt = RMSprop(lr = dis_lr, decay = dis_decay)

adv_lr = dis_lr * 0.5
adv_decay = dis_decay * 0.5
adv_opt = RMSprop(lr = adv_lr, decay = adv_decay)

test_size = 16
batch_size = 64
epochs = 20000

save_intervals = 5000
save_adress = "./"

# %%
'''Download dataset'''
(x_train, y_train), (x_test, _) = mnist.load_data()
x_train = x_train.reshape(-1, image_size, image_size, 1).astype("float32") / 255
y_train = to_categorical(y_train)
# Out:
# Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
'''BatchNormalization-Relu is used repeatedly so get it into a function'''
def BN_RELU(x):

    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    return x

# %%
'''Build Generator'''
def build_generator(z_inputs, label_inputs, image_size = 28):

    image_size = image_size // 4

    x = concatenate([z_inputs, label_inputs])
    x = Dense(image_size * image_size * gen_filters[0])(x)
    x = Reshape((image_size, image_size, gen_filters[0]))(x)

    for stride, filter in zip(gen_strides, gen_filters):
        x = BN_RELU(x)
        x = Conv2DTranspose(filters = filter,
                            strides = stride,
                            padding = "same",
                            kernel_size = kernel_size)(x)
    outputs = Activation("sigmoid")(x)

    model = Model([z_inputs, label_inputs], outputs, name = "Generator")
    model.summary()
    return model

# %%
def build_discriminator(inputs):

    x = inputs

    for stride, filter in zip(dis_strides, dis_filters):
        x = LeakyReLU(alpha = alpha)(x)
        x = Conv2D(filters = filter,
                   strides = stride,
                   padding = "same",
                   kernel_size = kernel_size)(x)
    y = Flatten()(x)
    x = Dense(1)(y)
    rf_outputs = Activation("sigmoid")(x)

    x = Dense(128)(y)
    x = Dense(10)(x)
    label_outputs = Activation("softmax")(x)

    model = Model(inputs, [rf_outputs, label_outputs], name = "Discriminator")
    model.summary()
    return model

# %%
"""Training phase"""
def train(models):

    gen, dis, adv = models
    test_noise = np.random.uniform(low = -1, high = 1, size =(test_size, latent_dim))
    test_labels = np.eye(10)[np.arange(batch_size) % 10]

    for epoch in range(1, epochs + 1): # (+ 1) for running plot function
        random_indices = np.random.randint(low = 0, high = x_train.shape[0], size = batch_size)
        real_imgs = x_train[random_indices]
        real_rf = np.ones(shape = (batch_size, 1))
        real_labels = y_train[random_indices]

        z = np.random.uniform(low = -1, high = 1, size =(batch_size, latent_dim))
        fake_labels = np.eye(10)[np.arange(batch_size) % 10]
        fake_imgs = gen.predict([z, fake_labels])
        fake_rf = np.zeros(shape = (batch_size, 1))

        dis_x = np.concatenate([real_imgs, fake_imgs])
        dis_rf_y = np.concatenate([real_rf, fake_rf])
        dis_labels_y = np.concatenate([real_labels, fake_labels])

        loss, _, _, _, _ = dis.train_on_batch(dis_x, [dis_rf_y, dis_labels_y])

        log = "step:{} dis[loss:{:3f}]".format(epoch, loss)

        adv_z_x = np.random.uniform( low=-1, high=1, size=(batch_size, latent_dim) )
        adv_labels_x = np.eye(10)[np.arange(batch_size) % 10]
        adv_rf_y = np.ones(shape = (batch_size, 1))

        loss, _, _, _, _ = adv.train_on_batch([adv_z_x, adv_labels_x], [adv_rf_y, adv_labels_x])

        log += " adv[loss:{:3f}]".format( loss )

        print(log)

        if epoch % save_intervals == 0:
            plot_image(gen, test_noise,test_labels, epoch)

# %%
"""Show what is being produced"""
def plot_image(generator, input_noise,labels,  step, show = False):

    z = input_noise
    n_images = z.shape[0]
    images = generator.predict([z, labels])

    rows = np.sqrt(n_images)

    plt.figure(figsize=(2,2))

    for i in range(n_images):
        plt.subplot(rows, rows, i+1)
        plt.imshow(images[i].reshape(image_size, image_size), cmap="gray")
        plt.axis("off")
    plt.savefig(os.path.join(save_adress, "step{}.png".format(step)))

    if show:
        plt.show()
    else:
        plt.close("all")

# %%
dis_inputs = Input(shape = image_shape)
dis = build_discriminator(dis_inputs)
dis.compile(optimizer = dis_opt,
            loss = ["binary_crossentropy", "categorical_crossentropy"],
            metrics = ["acc"])

gen_z_inputs = Input(shape = (latent_dim,))
gen_label_inputs = Input( shape=(10,) )
gen = build_generator(z_inputs=gen_z_inputs, label_inputs=gen_label_inputs)

dis.trainable = False
adv_inputs = [gen_z_inputs, gen_label_inputs]
adv_outputs = dis(gen(adv_inputs))
adv = Model(adv_inputs, adv_outputs, name="Adversarial")
adv.summary()
adv.compile(optimizer = adv_opt,
            loss = ["binary_crossentropy", "categorical_crossentropy"],
            metrics = ["acc"])

models = gen, dis, adv
train(models)
# Out:
# Model: "Discriminator"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 28, 28, 1)    0
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 28, 28, 1)    0           input_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 14, 14, 32)   832         leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 14, 14, 32)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 7, 7, 64)     51264       leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 7, 7, 64)     0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 4, 4, 128)    204928      leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 4, 4, 128)    0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 4, 4, 256)    819456      leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 4096)         0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 128)          524416      flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1)            4097        flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 10)           1290        dense_6[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 1)            0           dense_5[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 10)           0           dense_7[0][0]
# ==================================================================================================
# Total params: 1,606,283
# Trainable params: 1,606,283
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "Generator"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            (None, 100)          0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            (None, 10)           0
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 110)          0           input_5[0][0]
#                                                                  input_6[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 6272)         696192      concatenate_2[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 7, 7, 128)    0           dense_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 7, 7, 128)    512         reshape_2[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 7, 7, 128)    0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 14, 14, 128)  409728      activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 14, 14, 128)  512         conv2d_transpose_5[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 14, 14, 128)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 28, 28, 64)   204864      activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 28, 28, 64)   256         conv2d_transpose_6[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 28, 28, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 28, 28, 32)   51232       activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 28, 28, 32)   128         conv2d_transpose_7[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 28, 28, 32)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 28, 28, 1)    801         activation_13[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 28, 28, 1)    0           conv2d_transpose_8[0][0]
# ==================================================================================================
# Total params: 1,364,225
# Trainable params: 1,363,521
# Non-trainable params: 704
# __________________________________________________________________________________________________
# Model: "Adversarial"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            (None, 100)          0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            (None, 10)           0
# __________________________________________________________________________________________________
# Generator (Model)               (None, 28, 28, 1)    1364225     input_5[0][0]
#                                                                  input_6[0][0]
# __________________________________________________________________________________________________
# Discriminator (Model)           [(None, 1), (None, 1 1606283     Generator[1][0]
# ==================================================================================================
# Total params: 2,970,508
# Trainable params: 1,363,521
# Non-trainable params: 1,606,987
# __________________________________________________________________________________________________
# /tensorflow-1.15.2/python3.6/keras/engine/training.py:297: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# step:1 dis[loss:2.995783] adv[loss:3.269300]
# step:2 dis[loss:2.900733] adv[loss:3.528508]
# /tensorflow-1.15.2/python3.6/keras/engine/training.py:297: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# Streaming output truncated to the last 5000 lines.
# step:15002 dis[loss:0.624043] adv[loss:0.771422]
# step:15003 dis[loss:0.630491] adv[loss:0.916233]
# step:15004 dis[loss:0.684539] adv[loss:0.739770]
# step:15005 dis[loss:0.703517] adv[loss:0.875637]
# step:15006 dis[loss:0.668193] adv[loss:0.789590]
# step:15007 dis[loss:0.662731] adv[loss:1.049889]
# step:15008 dis[loss:0.617116] adv[loss:0.715945]
# step:15009 dis[loss:0.639165] adv[loss:0.839920]
# step:15010 dis[loss:0.618740] adv[loss:0.660220]
# step:15011 dis[loss:0.664738] adv[loss:1.036508]
# step:15012 dis[loss:0.625084] adv[loss:0.609064]
# step:15013 dis[loss:0.678445] adv[loss:1.111297]
# step:15014 dis[loss:0.646102] adv[loss:0.664545]
# step:15015 dis[loss:0.686435] adv[loss:1.024926]
# step:15016 dis[loss:0.658708] adv[loss:0.891297]
# step:15017 dis[loss:0.622089] adv[loss:0.855539]
# step:15018 dis[loss:0.622839] adv[loss:1.029490]
# step:15019 dis[loss:0.641056] adv[loss:0.668387]
# step:15020 dis[loss:0.673677] adv[loss:1.077253]
# step:15021 dis[loss:0.646861] adv[loss:0.641025]
# step:15022 dis[loss:0.650385] adv[loss:1.083436]
# step:15023 dis[loss:0.702975] adv[loss:0.663930]
# step:15024 dis[loss:0.631806] adv[loss:0.988536]
# step:15025 dis[loss:0.651633] adv[loss:0.615411]
# step:15026 dis[loss:0.683057] adv[loss:0.983467]
# step:15027 dis[loss:0.626474] adv[loss:0.752814]
# step:15028 dis[loss:0.644728] adv[loss:0.861647]
# step:15029 dis[loss:0.649993] adv[loss:0.711710]
# step:15030 dis[loss:0.621848] adv[loss:0.912501]
# step:15031 dis[loss:0.670461] adv[loss:0.798928]
# step:15032 dis[loss:0.657905] adv[loss:0.952728]
# step:15033 dis[loss:0.605903] adv[loss:0.741354]
# step:15034 dis[loss:0.647277] adv[loss:1.029797]
# step:15035 dis[loss:0.656190] adv[loss:0.658560]
# step:15036 dis[loss:0.672960] adv[loss:1.149409]
# step:15037 dis[loss:0.722744] adv[loss:0.607078]
# step:15038 dis[loss:0.658870] adv[loss:0.935987]
# step:15039 dis[loss:0.656223] adv[loss:0.639307]
# step:15040 dis[loss:0.651128] adv[loss:0.912202]
# step:15041 dis[loss:0.628582] adv[loss:0.663271]
# step:15042 dis[loss:0.656002] adv[loss:0.960258]
# step:15043 dis[loss:0.662796] adv[loss:0.606454]
# step:15044 dis[loss:0.643594] adv[loss:0.959645]
# step:15045 dis[loss:0.647668] adv[loss:0.829832]
# step:15046 dis[loss:0.651822] adv[loss:0.966226]
# step:15047 dis[loss:0.628979] adv[loss:0.769706]
# step:15048 dis[loss:0.667475] adv[loss:0.878470]
# step:15049 dis[loss:0.666031] adv[loss:0.782262]
# step:15050 dis[loss:0.610997] adv[loss:1.047707]
# step:15051 dis[loss:0.623134] adv[loss:0.784549]
# step:15052 dis[loss:0.647816] adv[loss:0.904482]
# step:15053 dis[loss:0.613885] adv[loss:0.733774]
# step:15054 dis[loss:0.658580] adv[loss:0.782273]
# step:15055 dis[loss:0.609173] adv[loss:1.131322]
# step:15056 dis[loss:0.654449] adv[loss:0.509350]
# step:15057 dis[loss:0.683387] adv[loss:1.268233]
# step:15058 dis[loss:0.706235] adv[loss:0.590618]
# step:15059 dis[loss:0.674126] adv[loss:1.018639]
# step:15060 dis[loss:0.663363] adv[loss:0.824054]
# step:15061 dis[loss:0.615078] adv[loss:0.900273]
# step:15062 dis[loss:0.682292] adv[loss:0.778009]
# step:15063 dis[loss:0.676424] adv[loss:0.877848]
# step:15064 dis[loss:0.643779] adv[loss:0.732269]
# step:15065 dis[loss:0.735711] adv[loss:0.826438]
# step:15066 dis[loss:0.673431] adv[loss:0.930934]
# step:15067 dis[loss:0.634147] adv[loss:0.760095]
# step:15068 dis[loss:0.618283] adv[loss:0.955619]
# step:15069 dis[loss:0.624164] adv[loss:0.816651]
# step:15070 dis[loss:0.636449] adv[loss:0.751086]
# step:15071 dis[loss:0.629918] adv[loss:0.886606]
# step:15072 dis[loss:0.636113] adv[loss:0.893941]
# step:15073 dis[loss:0.633435] adv[loss:0.785177]
# step:15074 dis[loss:0.638759] adv[loss:0.865347]
# step:15075 dis[loss:0.620153] adv[loss:0.659730]
# step:15076 dis[loss:0.682041] adv[loss:1.149305]
# step:15077 dis[loss:0.647188] adv[loss:0.576524]
# step:15078 dis[loss:0.605100] adv[loss:1.139371]
# step:15079 dis[loss:0.688091] adv[loss:0.614078]
# step:15080 dis[loss:0.668684] adv[loss:1.039163]
# step:15081 dis[loss:0.619796] adv[loss:0.634599]
# step:15082 dis[loss:0.661551] adv[loss:0.971124]
# step:15083 dis[loss:0.652591] adv[loss:0.700883]
# step:15084 dis[loss:0.658976] adv[loss:1.115215]
# step:15085 dis[loss:0.663639] adv[loss:0.651834]
# step:15086 dis[loss:0.672130] adv[loss:1.144374]
# step:15087 dis[loss:0.701019] adv[loss:0.640794]
# step:15088 dis[loss:0.729261] adv[loss:1.124640]
# step:15089 dis[loss:0.639103] adv[loss:0.771965]
# step:15090 dis[loss:0.605600] adv[loss:0.911045]
# step:15091 dis[loss:0.588971] adv[loss:0.775593]
# step:15092 dis[loss:0.651672] adv[loss:0.992418]
# step:15093 dis[loss:0.651470] adv[loss:0.689032]
# step:15094 dis[loss:0.656822] adv[loss:1.105563]
# step:15095 dis[loss:0.684725] adv[loss:0.577982]
# step:15096 dis[loss:0.657026] adv[loss:1.003591]
# step:15097 dis[loss:0.627834] adv[loss:0.613421]
# step:15098 dis[loss:0.688269] adv[loss:1.122599]
# step:15099 dis[loss:0.680512] adv[loss:0.703619]
# step:15100 dis[loss:0.665503] adv[loss:0.875785]
# step:15101 dis[loss:0.650249] adv[loss:0.849242]
# step:15102 dis[loss:0.635738] adv[loss:0.759801]
# step:15103 dis[loss:0.665648] adv[loss:0.842755]
# step:15104 dis[loss:0.644305] adv[loss:0.776942]
# step:15105 dis[loss:0.639171] adv[loss:0.819254]
# step:15106 dis[loss:0.679194] adv[loss:0.925234]
# step:15107 dis[loss:0.640039] adv[loss:0.870818]
# step:15108 dis[loss:0.684026] adv[loss:0.685891]
# step:15109 dis[loss:0.647282] adv[loss:1.003147]
# step:15110 dis[loss:0.628390] adv[loss:0.685280]
# step:15111 dis[loss:0.651731] adv[loss:1.115466]
# step:15112 dis[loss:0.685624] adv[loss:0.536624]
# step:15113 dis[loss:0.671885] adv[loss:1.092092]
# step:15114 dis[loss:0.678936] adv[loss:0.683433]
# step:15115 dis[loss:0.691615] adv[loss:0.892571]
# step:15116 dis[loss:0.654499] adv[loss:0.807336]
# step:15117 dis[loss:0.619477] adv[loss:0.896345]
# step:15118 dis[loss:0.662638] adv[loss:0.801160]
# step:15119 dis[loss:0.659543] adv[loss:0.951836]
# step:15120 dis[loss:0.612122] adv[loss:0.763569]
# step:15121 dis[loss:0.635785] adv[loss:0.835825]
# step:15122 dis[loss:0.647494] adv[loss:0.792812]
# step:15123 dis[loss:0.640177] adv[loss:0.887592]
# step:15124 dis[loss:0.648501] adv[loss:0.731735]
# step:15125 dis[loss:0.665704] adv[loss:0.952811]
# step:15126 dis[loss:0.664585] adv[loss:0.813961]
# step:15127 dis[loss:0.656841] adv[loss:0.961135]
# step:15128 dis[loss:0.620741] adv[loss:0.704328]
# step:15129 dis[loss:0.642652] adv[loss:1.066869]
# step:15130 dis[loss:0.644844] adv[loss:0.597637]
# step:15131 dis[loss:0.649515] adv[loss:1.008537]
# step:15132 dis[loss:0.651684] adv[loss:0.576128]
# step:15133 dis[loss:0.701800] adv[loss:1.027547]
# step:15134 dis[loss:0.634891] adv[loss:0.654540]
# step:15135 dis[loss:0.653846] adv[loss:1.051729]
# step:15136 dis[loss:0.626434] adv[loss:0.718937]
# step:15137 dis[loss:0.640617] adv[loss:1.041898]
# step:15138 dis[loss:0.652585] adv[loss:0.822440]
# step:15139 dis[loss:0.625145] adv[loss:0.915729]
# step:15140 dis[loss:0.679289] adv[loss:0.660579]
# step:15141 dis[loss:0.668967] adv[loss:1.009043]
# step:15142 dis[loss:0.644372] adv[loss:0.540142]
# step:15143 dis[loss:0.649379] adv[loss:1.127527]
# step:15144 dis[loss:0.656442] adv[loss:0.603442]
# step:15145 dis[loss:0.711984] adv[loss:1.174755]
# step:15146 dis[loss:0.636793] adv[loss:0.680275]
# step:15147 dis[loss:0.681833] adv[loss:1.144276]
# step:15148 dis[loss:0.640584] adv[loss:0.586312]
# step:15149 dis[loss:0.671203] adv[loss:0.942878]
# step:15150 dis[loss:0.649258] adv[loss:0.699940]
# step:15151 dis[loss:0.675837] adv[loss:0.809005]
# step:15152 dis[loss:0.659896] adv[loss:0.796583]
# step:15153 dis[loss:0.641437] adv[loss:0.856269]
# step:15154 dis[loss:0.636412] adv[loss:0.720160]
# step:15155 dis[loss:0.648228] adv[loss:0.821129]
# step:15156 dis[loss:0.625588] adv[loss:0.826941]
# step:15157 dis[loss:0.629541] adv[loss:0.811458]
# step:15158 dis[loss:0.655516] adv[loss:0.814070]
# step:15159 dis[loss:0.630449] adv[loss:0.738184]
# step:15160 dis[loss:0.659265] adv[loss:0.905126]
# step:15161 dis[loss:0.670349] adv[loss:0.773196]
# step:15162 dis[loss:0.667025] adv[loss:1.071348]
# step:15163 dis[loss:0.663414] adv[loss:0.601720]
# step:15164 dis[loss:0.697412] adv[loss:1.201517]
# step:15165 dis[loss:0.692404] adv[loss:0.599852]
# step:15166 dis[loss:0.681608] adv[loss:1.016083]
# step:15167 dis[loss:0.691385] adv[loss:0.671589]
# step:15168 dis[loss:0.730215] adv[loss:0.913727]
# step:15169 dis[loss:0.647124] adv[loss:0.802900]
# step:15170 dis[loss:0.643159] adv[loss:0.879546]
# step:15171 dis[loss:0.649938] adv[loss:0.885114]
# step:15172 dis[loss:0.671410] adv[loss:0.821861]
# step:15173 dis[loss:0.683003] adv[loss:0.931569]
# step:15174 dis[loss:0.654847] adv[loss:0.675104]
# step:15175 dis[loss:0.642964] adv[loss:1.023580]
# step:15176 dis[loss:0.639492] adv[loss:0.641278]
# step:15177 dis[loss:0.635175] adv[loss:1.101899]
# step:15178 dis[loss:0.680387] adv[loss:0.564834]
# step:15179 dis[loss:0.683743] adv[loss:1.149352]
# step:15180 dis[loss:0.624479] adv[loss:0.818504]
# step:15181 dis[loss:0.643856] adv[loss:0.839333]
# step:15182 dis[loss:0.622240] adv[loss:0.951780]
# step:15183 dis[loss:0.635674] adv[loss:0.728401]
# step:15184 dis[loss:0.614499] adv[loss:1.027747]
# step:15185 dis[loss:0.652340] adv[loss:0.693318]
# step:15186 dis[loss:0.695248] adv[loss:1.001998]
# step:15187 dis[loss:0.649403] adv[loss:0.737270]
# step:15188 dis[loss:0.659276] adv[loss:0.918150]
# step:15189 dis[loss:0.661231] adv[loss:0.757294]
# step:15190 dis[loss:0.652256] adv[loss:0.924504]
# step:15191 dis[loss:0.640884] adv[loss:0.830013]
# step:15192 dis[loss:0.629174] adv[loss:0.832369]
# step:15193 dis[loss:0.638677] adv[loss:0.820513]
# step:15194 dis[loss:0.647112] adv[loss:0.855376]
# step:15195 dis[loss:0.644002] adv[loss:0.719255]
# step:15196 dis[loss:0.680234] adv[loss:0.950758]
# step:15197 dis[loss:0.655228] adv[loss:0.548330]
# step:15198 dis[loss:0.691239] adv[loss:1.035601]
# step:15199 dis[loss:0.687287] adv[loss:0.646773]
# step:15200 dis[loss:0.741272] adv[loss:1.080801]
# step:15201 dis[loss:0.636065] adv[loss:0.744025]
# step:15202 dis[loss:0.663516] adv[loss:1.088429]
# step:15203 dis[loss:0.680818] adv[loss:0.785353]
# step:15204 dis[loss:0.617016] adv[loss:0.986601]
# step:15205 dis[loss:0.701191] adv[loss:0.835706]
# step:15206 dis[loss:0.614647] adv[loss:0.930630]
# step:15207 dis[loss:0.642526] adv[loss:0.747155]
# step:15208 dis[loss:0.614456] adv[loss:0.947769]
# step:15209 dis[loss:0.665678] adv[loss:0.663984]
# step:15210 dis[loss:0.648024] adv[loss:0.903154]
# step:15211 dis[loss:0.623572] adv[loss:0.799171]
# step:15212 dis[loss:0.635517] adv[loss:0.999655]
# step:15213 dis[loss:0.681882] adv[loss:0.830983]
# step:15214 dis[loss:0.636163] adv[loss:1.074837]
# step:15215 dis[loss:0.656829] adv[loss:0.619884]
# step:15216 dis[loss:0.652769] adv[loss:1.342090]
# step:15217 dis[loss:0.708846] adv[loss:0.571733]
# step:15218 dis[loss:0.660624] adv[loss:1.006089]
# step:15219 dis[loss:0.667952] adv[loss:0.846121]
# step:15220 dis[loss:0.604038] adv[loss:0.845573]
# step:15221 dis[loss:0.656129] adv[loss:0.900698]
# step:15222 dis[loss:0.643817] adv[loss:0.658970]
# step:15223 dis[loss:0.674804] adv[loss:0.956112]
# step:15224 dis[loss:0.649875] adv[loss:0.653836]
# step:15225 dis[loss:0.603559] adv[loss:1.032402]
# step:15226 dis[loss:0.641215] adv[loss:0.661310]
# step:15227 dis[loss:0.653584] adv[loss:1.024321]
# step:15228 dis[loss:0.668564] adv[loss:0.873134]
# step:15229 dis[loss:0.634337] adv[loss:0.871015]
# step:15230 dis[loss:0.665700] adv[loss:0.760533]
# step:15231 dis[loss:0.667037] adv[loss:0.990466]
# step:15232 dis[loss:0.651090] adv[loss:0.699394]
# step:15233 dis[loss:0.613903] adv[loss:1.011915]
# step:15234 dis[loss:0.655465] adv[loss:0.616442]
# step:15235 dis[loss:0.659121] adv[loss:1.099048]
# step:15236 dis[loss:0.668090] adv[loss:0.583789]
# step:15237 dis[loss:0.612726] adv[loss:1.171021]
# step:15238 dis[loss:0.692953] adv[loss:0.849557]
# step:15239 dis[loss:0.691056] adv[loss:0.933569]
# step:15240 dis[loss:0.689326] adv[loss:0.764153]
# step:15241 dis[loss:0.687085] adv[loss:0.939306]
# step:15242 dis[loss:0.641717] adv[loss:0.767855]
# step:15243 dis[loss:0.630705] adv[loss:0.982340]
# step:15244 dis[loss:0.668466] adv[loss:0.714870]
# step:15245 dis[loss:0.627232] adv[loss:1.025879]
# step:15246 dis[loss:0.610654] adv[loss:0.631513]
# step:15247 dis[loss:0.669714] adv[loss:1.160802]
# step:15248 dis[loss:0.639275] adv[loss:0.587291]
# step:15249 dis[loss:0.638093] adv[loss:1.085340]
# step:15250 dis[loss:0.658981] adv[loss:0.678738]
# step:15251 dis[loss:0.664322] adv[loss:1.027744]
# step:15252 dis[loss:0.726805] adv[loss:0.756562]
# step:15253 dis[loss:0.641362] adv[loss:0.889739]
# step:15254 dis[loss:0.676858] adv[loss:0.931064]
# step:15255 dis[loss:0.622397] adv[loss:0.826789]
# step:15256 dis[loss:0.650080] adv[loss:0.927181]
# step:15257 dis[loss:0.659263] adv[loss:0.854426]
# step:15258 dis[loss:0.625471] adv[loss:0.712319]
# step:15259 dis[loss:0.649908] adv[loss:0.919928]
# step:15260 dis[loss:0.646579] adv[loss:0.677738]
# step:15261 dis[loss:0.651890] adv[loss:1.211420]
# step:15262 dis[loss:0.633939] adv[loss:0.542611]
# step:15263 dis[loss:0.683107] adv[loss:1.234100]
# step:15264 dis[loss:0.694724] adv[loss:0.628745]
# step:15265 dis[loss:0.706985] adv[loss:1.021315]
# step:15266 dis[loss:0.651081] adv[loss:0.776523]
# step:15267 dis[loss:0.696992] adv[loss:0.951881]
# step:15268 dis[loss:0.618737] adv[loss:0.866497]
# step:15269 dis[loss:0.646304] adv[loss:0.811308]
# step:15270 dis[loss:0.696005] adv[loss:0.811400]
# step:15271 dis[loss:0.624627] adv[loss:0.782700]
# step:15272 dis[loss:0.642086] adv[loss:0.914716]
# step:15273 dis[loss:0.690091] adv[loss:0.765536]
# step:15274 dis[loss:0.610549] adv[loss:1.160868]
# step:15275 dis[loss:0.669766] adv[loss:0.710090]
# step:15276 dis[loss:0.702446] adv[loss:1.094950]
# step:15277 dis[loss:0.677758] adv[loss:0.590408]
# step:15278 dis[loss:0.664724] adv[loss:1.044656]
# step:15279 dis[loss:0.633602] adv[loss:0.701818]
# step:15280 dis[loss:0.671860] adv[loss:1.032031]
# step:15281 dis[loss:0.650314] adv[loss:0.663601]
# step:15282 dis[loss:0.669111] adv[loss:1.143572]
# step:15283 dis[loss:0.676726] adv[loss:0.658732]
# step:15284 dis[loss:0.642220] adv[loss:1.077953]
# step:15285 dis[loss:0.639685] adv[loss:0.664048]
# step:15286 dis[loss:0.652569] adv[loss:1.019712]
# step:15287 dis[loss:0.668610] adv[loss:0.644028]
# step:15288 dis[loss:0.670841] adv[loss:0.888339]
# step:15289 dis[loss:0.658886] adv[loss:0.700258]
# step:15290 dis[loss:0.641842] adv[loss:0.867485]
# step:15291 dis[loss:0.696917] adv[loss:0.819206]
# step:15292 dis[loss:0.675926] adv[loss:0.886617]
# step:15293 dis[loss:0.670412] adv[loss:0.662518]
# step:15294 dis[loss:0.648143] adv[loss:1.035541]
# step:15295 dis[loss:0.667499] adv[loss:0.621626]
# step:15296 dis[loss:0.654035] adv[loss:0.921215]
# step:15297 dis[loss:0.702782] adv[loss:0.707417]
# step:15298 dis[loss:0.702977] adv[loss:0.966198]
# step:15299 dis[loss:0.685780] adv[loss:0.743166]
# step:15300 dis[loss:0.638279] adv[loss:0.856203]
# step:15301 dis[loss:0.639724] adv[loss:0.787637]
# step:15302 dis[loss:0.678548] adv[loss:0.887719]
# step:15303 dis[loss:0.643722] adv[loss:0.803223]
# step:15304 dis[loss:0.645335] adv[loss:0.868403]
# step:15305 dis[loss:0.682350] adv[loss:0.792717]
# step:15306 dis[loss:0.644526] adv[loss:0.745919]
# step:15307 dis[loss:0.653410] adv[loss:1.003523]
# step:15308 dis[loss:0.663697] adv[loss:0.707218]
# step:15309 dis[loss:0.670042] adv[loss:1.070723]
# step:15310 dis[loss:0.633659] adv[loss:0.644970]
# step:15311 dis[loss:0.670719] adv[loss:1.031398]
# step:15312 dis[loss:0.664925] adv[loss:0.633578]
# step:15313 dis[loss:0.642006] adv[loss:1.035674]
# step:15314 dis[loss:0.652278] adv[loss:0.551626]
# step:15315 dis[loss:0.643244] adv[loss:1.075097]
# step:15316 dis[loss:0.682693] adv[loss:0.684835]
# step:15317 dis[loss:0.629726] adv[loss:0.908682]
# step:15318 dis[loss:0.688161] adv[loss:0.780995]
# step:15319 dis[loss:0.673552] adv[loss:0.908164]
# step:15320 dis[loss:0.653071] adv[loss:0.648732]
# step:15321 dis[loss:0.672027] adv[loss:1.009266]
# step:15322 dis[loss:0.655969] adv[loss:0.675044]
# step:15323 dis[loss:0.668945] adv[loss:0.968706]
# step:15324 dis[loss:0.607843] adv[loss:0.655961]
# step:15325 dis[loss:0.696111] adv[loss:0.907167]
# step:15326 dis[loss:0.651426] adv[loss:0.869305]
# step:15327 dis[loss:0.667317] adv[loss:0.809167]
# step:15328 dis[loss:0.611061] adv[loss:1.031002]
# step:15329 dis[loss:0.659020] adv[loss:0.695575]
# step:15330 dis[loss:0.670968] adv[loss:0.963809]
# step:15331 dis[loss:0.618973] adv[loss:0.764834]
# step:15332 dis[loss:0.678817] adv[loss:1.081717]
# step:15333 dis[loss:0.704459] adv[loss:0.606876]
# step:15334 dis[loss:0.701326] adv[loss:1.015605]
# step:15335 dis[loss:0.698159] adv[loss:0.573029]
# step:15336 dis[loss:0.689170] adv[loss:1.114717]
# step:15337 dis[loss:0.660841] adv[loss:0.710947]
# step:15338 dis[loss:0.658644] adv[loss:1.067852]
# step:15339 dis[loss:0.602321] adv[loss:0.750807]
# step:15340 dis[loss:0.653501] adv[loss:0.794378]
# step:15341 dis[loss:0.594050] adv[loss:0.856109]
# step:15342 dis[loss:0.669011] adv[loss:0.847211]
# step:15343 dis[loss:0.640473] adv[loss:0.713811]
# step:15344 dis[loss:0.711413] adv[loss:0.971322]
# step:15345 dis[loss:0.667669] adv[loss:0.659313]
# step:15346 dis[loss:0.654721] adv[loss:1.055755]
# step:15347 dis[loss:0.648181] adv[loss:0.634612]
# step:15348 dis[loss:0.651341] adv[loss:1.182280]
# step:15349 dis[loss:0.649488] adv[loss:0.637941]
# step:15350 dis[loss:0.647478] adv[loss:1.055653]
# step:15351 dis[loss:0.673491] adv[loss:0.613150]
# step:15352 dis[loss:0.640190] adv[loss:1.029311]
# step:15353 dis[loss:0.661440] adv[loss:0.705662]
# step:15354 dis[loss:0.649233] adv[loss:0.941885]
# step:15355 dis[loss:0.619394] adv[loss:0.872865]
# step:15356 dis[loss:0.718896] adv[loss:0.735331]
# step:15357 dis[loss:0.659445] adv[loss:0.996328]
# step:15358 dis[loss:0.613091] adv[loss:0.737665]
# step:15359 dis[loss:0.628656] adv[loss:0.962932]
# step:15360 dis[loss:0.650980] adv[loss:0.724564]
# step:15361 dis[loss:0.675681] adv[loss:0.993794]
# step:15362 dis[loss:0.633391] adv[loss:0.619272]
# step:15363 dis[loss:0.672520] adv[loss:1.024552]
# step:15364 dis[loss:0.666775] adv[loss:0.675868]
# step:15365 dis[loss:0.632563] adv[loss:0.926843]
# step:15366 dis[loss:0.662280] adv[loss:0.659019]
# step:15367 dis[loss:0.618565] adv[loss:0.968601]
# step:15368 dis[loss:0.639130] adv[loss:0.620590]
# step:15369 dis[loss:0.659716] adv[loss:1.194531]
# step:15370 dis[loss:0.726790] adv[loss:0.694892]
# step:15371 dis[loss:0.633690] adv[loss:0.978010]
# step:15372 dis[loss:0.656087] adv[loss:0.770789]
# step:15373 dis[loss:0.662405] adv[loss:0.880974]
# step:15374 dis[loss:0.671849] adv[loss:0.826125]
# step:15375 dis[loss:0.621678] adv[loss:0.819860]
# step:15376 dis[loss:0.652448] adv[loss:0.719135]
# step:15377 dis[loss:0.632715] adv[loss:1.058023]
# step:15378 dis[loss:0.659969] adv[loss:0.651545]
# step:15379 dis[loss:0.685602] adv[loss:0.945859]
# step:15380 dis[loss:0.635792] adv[loss:0.719844]
# step:15381 dis[loss:0.650194] adv[loss:1.013968]
# step:15382 dis[loss:0.667181] adv[loss:0.602486]
# step:15383 dis[loss:0.655599] adv[loss:1.043959]
# step:15384 dis[loss:0.671807] adv[loss:0.674651]
# step:15385 dis[loss:0.667767] adv[loss:1.067948]
# step:15386 dis[loss:0.699717] adv[loss:0.797147]
# step:15387 dis[loss:0.620958] adv[loss:0.862356]
# step:15388 dis[loss:0.626745] adv[loss:0.770187]
# step:15389 dis[loss:0.634075] adv[loss:1.055102]
# step:15390 dis[loss:0.615566] adv[loss:0.657643]
# step:15391 dis[loss:0.649251] adv[loss:0.970772]
# step:15392 dis[loss:0.626611] adv[loss:0.621339]
# step:15393 dis[loss:0.658628] adv[loss:1.183202]
# step:15394 dis[loss:0.650424] adv[loss:0.621098]
# step:15395 dis[loss:0.721114] adv[loss:1.073073]
# step:15396 dis[loss:0.662120] adv[loss:0.664124]
# step:15397 dis[loss:0.636050] adv[loss:0.992248]
# step:15398 dis[loss:0.634391] adv[loss:0.692115]
# step:15399 dis[loss:0.622111] adv[loss:0.828355]
# step:15400 dis[loss:0.627514] adv[loss:0.896037]
# step:15401 dis[loss:0.637357] adv[loss:0.800538]
# step:15402 dis[loss:0.664437] adv[loss:0.869219]
# step:15403 dis[loss:0.621758] adv[loss:0.860161]
# step:15404 dis[loss:0.652261] adv[loss:0.928705]
# step:15405 dis[loss:0.637381] adv[loss:0.617159]
# step:15406 dis[loss:0.709243] adv[loss:1.257986]
# step:15407 dis[loss:0.682931] adv[loss:0.586799]
# step:15408 dis[loss:0.659370] adv[loss:1.041810]
# step:15409 dis[loss:0.670396] adv[loss:0.698305]
# step:15410 dis[loss:0.641159] adv[loss:0.931050]
# step:15411 dis[loss:0.634732] adv[loss:0.715359]
# step:15412 dis[loss:0.663819] adv[loss:0.781092]
# step:15413 dis[loss:0.664959] adv[loss:0.923855]
# step:15414 dis[loss:0.617422] adv[loss:0.801347]
# step:15415 dis[loss:0.620520] adv[loss:0.801688]
# step:15416 dis[loss:0.641738] adv[loss:0.792773]
# step:15417 dis[loss:0.636469] adv[loss:0.740446]
# step:15418 dis[loss:0.649654] adv[loss:0.828462]
# step:15419 dis[loss:0.626727] adv[loss:0.790445]
# step:15420 dis[loss:0.640731] adv[loss:0.754136]
# step:15421 dis[loss:0.640208] adv[loss:0.718528]
# step:15422 dis[loss:0.640434] adv[loss:1.111842]
# step:15423 dis[loss:0.622134] adv[loss:0.597613]
# step:15424 dis[loss:0.721715] adv[loss:1.032273]
# step:15425 dis[loss:0.666794] adv[loss:0.625119]
# step:15426 dis[loss:0.655972] adv[loss:1.129010]
# step:15427 dis[loss:0.657380] adv[loss:0.702557]
# step:15428 dis[loss:0.611584] adv[loss:1.003733]
# step:15429 dis[loss:0.694351] adv[loss:0.683816]
# step:15430 dis[loss:0.659379] adv[loss:1.015660]
# step:15431 dis[loss:0.630587] adv[loss:0.676205]
# step:15432 dis[loss:0.615401] adv[loss:1.123028]
# step:15433 dis[loss:0.660293] adv[loss:0.543340]
# step:15434 dis[loss:0.657416] adv[loss:1.165072]
# step:15435 dis[loss:0.677998] adv[loss:0.710967]
# step:15436 dis[loss:0.619253] adv[loss:1.014187]
# step:15437 dis[loss:0.684379] adv[loss:0.732648]
# step:15438 dis[loss:0.643098] adv[loss:0.827496]
# step:15439 dis[loss:0.664423] adv[loss:0.824005]
# step:15440 dis[loss:0.625352] adv[loss:0.710018]
# step:15441 dis[loss:0.672257] adv[loss:0.987970]
# step:15442 dis[loss:0.635218] adv[loss:0.764465]
# step:15443 dis[loss:0.628228] adv[loss:1.085084]
# step:15444 dis[loss:0.632158] adv[loss:0.700469]
# step:15445 dis[loss:0.638405] adv[loss:0.863797]
# step:15446 dis[loss:0.657626] adv[loss:0.866508]
# step:15447 dis[loss:0.653130] adv[loss:0.734015]
# step:15448 dis[loss:0.654337] adv[loss:0.890537]
# step:15449 dis[loss:0.659702] adv[loss:0.792799]
# step:15450 dis[loss:0.666750] adv[loss:0.828034]
# step:15451 dis[loss:0.693482] adv[loss:0.775748]
# step:15452 dis[loss:0.622865] adv[loss:0.830266]
# step:15453 dis[loss:0.677539] adv[loss:0.881170]
# step:15454 dis[loss:0.614850] adv[loss:0.883549]
# step:15455 dis[loss:0.638877] adv[loss:0.925586]
# step:15456 dis[loss:0.648927] adv[loss:0.913843]
# step:15457 dis[loss:0.673707] adv[loss:0.698874]
# step:15458 dis[loss:0.629110] adv[loss:0.748360]
# step:15459 dis[loss:0.653261] adv[loss:0.940499]
# step:15460 dis[loss:0.672606] adv[loss:0.734225]
# step:15461 dis[loss:0.637859] adv[loss:1.105739]
# step:15462 dis[loss:0.709265] adv[loss:0.683667]
# step:15463 dis[loss:0.652966] adv[loss:1.053671]
# step:15464 dis[loss:0.654488] adv[loss:0.650250]
# step:15465 dis[loss:0.601986] adv[loss:1.069944]
# step:15466 dis[loss:0.620948] adv[loss:0.622523]
# step:15467 dis[loss:0.687243] adv[loss:1.113462]
# step:15468 dis[loss:0.687653] adv[loss:0.543526]
# step:15469 dis[loss:0.683720] adv[loss:1.119315]
# step:15470 dis[loss:0.677466] adv[loss:0.718063]
# step:15471 dis[loss:0.671819] adv[loss:0.870562]
# step:15472 dis[loss:0.639950] adv[loss:0.771861]
# step:15473 dis[loss:0.655945] adv[loss:0.848678]
# step:15474 dis[loss:0.631883] adv[loss:0.809663]
# step:15475 dis[loss:0.634951] adv[loss:0.842668]
# step:15476 dis[loss:0.645094] adv[loss:0.778946]
# step:15477 dis[loss:0.645515] adv[loss:0.949666]
# step:15478 dis[loss:0.649632] adv[loss:0.720898]
# step:15479 dis[loss:0.688844] adv[loss:1.084191]
# step:15480 dis[loss:0.682643] adv[loss:0.620188]
# step:15481 dis[loss:0.677002] adv[loss:1.167892]
# step:15482 dis[loss:0.676060] adv[loss:0.681013]
# step:15483 dis[loss:0.693189] adv[loss:0.966806]
# step:15484 dis[loss:0.666096] adv[loss:0.744064]
# step:15485 dis[loss:0.670941] adv[loss:1.159477]
# step:15486 dis[loss:0.610330] adv[loss:0.789099]
# step:15487 dis[loss:0.625074] adv[loss:0.861333]
# step:15488 dis[loss:0.646431] adv[loss:0.735561]
# step:15489 dis[loss:0.910360] adv[loss:0.892475]
# step:15490 dis[loss:0.635382] adv[loss:0.753265]
# step:15491 dis[loss:0.658750] adv[loss:0.873512]
# step:15492 dis[loss:0.668894] adv[loss:0.745027]
# step:15493 dis[loss:0.662063] adv[loss:1.058011]
# step:15494 dis[loss:0.679032] adv[loss:0.630479]
# step:15495 dis[loss:0.654341] adv[loss:1.279373]
# step:15496 dis[loss:0.666635] adv[loss:0.626699]
# step:15497 dis[loss:0.598136] adv[loss:1.135862]
# step:15498 dis[loss:0.678522] adv[loss:0.693105]
# step:15499 dis[loss:0.641800] adv[loss:1.021586]
# step:15500 dis[loss:0.652116] adv[loss:0.678120]
# step:15501 dis[loss:0.667708] adv[loss:0.956434]
# step:15502 dis[loss:0.602068] adv[loss:0.807203]
# step:15503 dis[loss:0.640697] adv[loss:0.804322]
# step:15504 dis[loss:0.643778] adv[loss:1.017846]
# step:15505 dis[loss:0.692848] adv[loss:0.763509]
# step:15506 dis[loss:0.670487] adv[loss:0.944074]
# step:15507 dis[loss:0.653613] adv[loss:0.612581]
# step:15508 dis[loss:0.681585] adv[loss:0.988427]
# step:15509 dis[loss:0.623757] adv[loss:0.710959]
# step:15510 dis[loss:0.682917] adv[loss:0.915541]
# step:15511 dis[loss:0.594824] adv[loss:0.783419]
# step:15512 dis[loss:0.641705] adv[loss:0.797261]
# step:15513 dis[loss:0.657593] adv[loss:0.766612]
# step:15514 dis[loss:0.639891] adv[loss:0.907152]
# step:15515 dis[loss:0.679537] adv[loss:0.809560]
# step:15516 dis[loss:0.627636] adv[loss:0.746920]
# step:15517 dis[loss:0.604428] adv[loss:1.125918]
# step:15518 dis[loss:0.637887] adv[loss:0.538892]
# step:15519 dis[loss:0.731642] adv[loss:1.055854]
# step:15520 dis[loss:0.627455] adv[loss:0.625883]
# step:15521 dis[loss:0.666024] adv[loss:1.095081]
# step:15522 dis[loss:0.700759] adv[loss:0.597544]
# step:15523 dis[loss:0.631780] adv[loss:1.005407]
# step:15524 dis[loss:0.644836] adv[loss:0.683067]
# step:15525 dis[loss:0.629055] adv[loss:0.952510]
# step:15526 dis[loss:0.644692] adv[loss:0.651459]
# step:15527 dis[loss:0.664405] adv[loss:0.944065]
# step:15528 dis[loss:0.634238] adv[loss:0.979186]
# step:15529 dis[loss:0.632145] adv[loss:0.814139]
# step:15530 dis[loss:0.641108] adv[loss:0.959247]
# step:15531 dis[loss:0.628091] adv[loss:0.752606]
# step:15532 dis[loss:0.623333] adv[loss:1.046149]
# step:15533 dis[loss:0.636677] adv[loss:0.653679]
# step:15534 dis[loss:0.636498] adv[loss:1.108963]
# step:15535 dis[loss:0.738443] adv[loss:0.589108]
# step:15536 dis[loss:0.708486] adv[loss:1.109018]
# step:15537 dis[loss:0.663288] adv[loss:0.674097]
# step:15538 dis[loss:0.676002] adv[loss:1.011433]
# step:15539 dis[loss:0.672570] adv[loss:0.695340]
# step:15540 dis[loss:0.652768] adv[loss:0.983190]
# step:15541 dis[loss:0.664241] adv[loss:0.768856]
# step:15542 dis[loss:0.652473] adv[loss:0.896431]
# step:15543 dis[loss:0.637882] adv[loss:0.811752]
# step:15544 dis[loss:0.673701] adv[loss:1.005533]
# step:15545 dis[loss:0.685021] adv[loss:0.668849]
# step:15546 dis[loss:0.675953] adv[loss:1.004897]
# step:15547 dis[loss:0.685516] adv[loss:0.732885]
# step:15548 dis[loss:0.664316] adv[loss:0.900199]
# step:15549 dis[loss:0.649632] adv[loss:0.808209]
# step:15550 dis[loss:0.666738] adv[loss:0.861831]
# step:15551 dis[loss:0.649155] adv[loss:0.783185]
# step:15552 dis[loss:0.623488] adv[loss:0.811672]
# step:15553 dis[loss:0.660215] adv[loss:0.944744]
# step:15554 dis[loss:0.623245] adv[loss:0.894568]
# step:15555 dis[loss:0.629745] adv[loss:0.782334]
# step:15556 dis[loss:0.611903] adv[loss:0.848605]
# step:15557 dis[loss:0.679212] adv[loss:1.008708]
# step:15558 dis[loss:0.619257] adv[loss:0.769529]
# step:15559 dis[loss:0.621002] adv[loss:0.980248]
# step:15560 dis[loss:0.658311] adv[loss:0.921603]
# step:15561 dis[loss:0.656496] adv[loss:0.828878]
# step:15562 dis[loss:0.671988] adv[loss:0.905966]
# step:15563 dis[loss:0.675817] adv[loss:0.832436]
# step:15564 dis[loss:0.645831] adv[loss:1.027958]
# step:15565 dis[loss:0.653505] adv[loss:0.508770]
# step:15566 dis[loss:0.706327] adv[loss:1.195821]
# step:15567 dis[loss:0.638633] adv[loss:0.630405]
# step:15568 dis[loss:0.691581] adv[loss:1.029803]
# step:15569 dis[loss:0.676386] adv[loss:0.667078]
# step:15570 dis[loss:0.675324] adv[loss:1.106974]
# step:15571 dis[loss:0.655164] adv[loss:0.739979]
# step:15572 dis[loss:0.647341] adv[loss:1.014175]
# step:15573 dis[loss:0.650235] adv[loss:0.754799]
# step:15574 dis[loss:0.641972] adv[loss:0.836715]
# step:15575 dis[loss:0.663680] adv[loss:0.870047]
# step:15576 dis[loss:0.609623] adv[loss:0.884776]
# step:15577 dis[loss:0.622655] adv[loss:0.799381]
# step:15578 dis[loss:0.651122] adv[loss:1.070175]
# step:15579 dis[loss:0.641249] adv[loss:0.679043]
# step:15580 dis[loss:0.660602] adv[loss:0.978014]
# step:15581 dis[loss:0.644659] adv[loss:0.674810]
# step:15582 dis[loss:0.668146] adv[loss:0.976609]
# step:15583 dis[loss:0.649489] adv[loss:0.609827]
# step:15584 dis[loss:0.666539] adv[loss:1.036700]
# step:15585 dis[loss:0.637707] adv[loss:0.651461]
# step:15586 dis[loss:0.640889] adv[loss:0.911028]
# step:15587 dis[loss:0.659927] adv[loss:0.721743]
# step:15588 dis[loss:0.658966] adv[loss:0.912770]
# step:15589 dis[loss:0.679363] adv[loss:0.650602]
# step:15590 dis[loss:0.653614] adv[loss:0.882065]
# step:15591 dis[loss:0.698895] adv[loss:0.723662]
# step:15592 dis[loss:0.661884] adv[loss:0.979042]
# step:15593 dis[loss:0.727145] adv[loss:0.634040]
# step:15594 dis[loss:0.659540] adv[loss:1.101314]
# step:15595 dis[loss:0.685634] adv[loss:0.623449]
# step:15596 dis[loss:0.701879] adv[loss:1.002595]
# step:15597 dis[loss:0.667982] adv[loss:0.707951]
# step:15598 dis[loss:0.615202] adv[loss:1.054095]
# step:15599 dis[loss:0.629240] adv[loss:0.714370]
# step:15600 dis[loss:0.645821] adv[loss:1.091554]
# step:15601 dis[loss:0.665282] adv[loss:0.647712]
# step:15602 dis[loss:0.695545] adv[loss:1.088968]
# step:15603 dis[loss:0.701688] adv[loss:0.687045]
# step:15604 dis[loss:0.649894] adv[loss:0.989549]
# step:15605 dis[loss:0.663554] adv[loss:0.798632]
# step:15606 dis[loss:0.655033] adv[loss:0.947050]
# step:15607 dis[loss:0.655970] adv[loss:0.774990]
# step:15608 dis[loss:0.692195] adv[loss:0.867181]
# step:15609 dis[loss:0.654938] adv[loss:0.896575]
# step:15610 dis[loss:0.636029] adv[loss:0.841500]
# step:15611 dis[loss:0.682583] adv[loss:0.809461]
# step:15612 dis[loss:0.624031] adv[loss:0.776437]
# step:15613 dis[loss:0.652776] adv[loss:0.798136]
# step:15614 dis[loss:0.615164] adv[loss:0.730104]
# step:15615 dis[loss:0.657731] adv[loss:0.969706]
# step:15616 dis[loss:0.646848] adv[loss:0.778295]
# step:15617 dis[loss:0.640205] adv[loss:1.038685]
# step:15618 dis[loss:0.619065] adv[loss:0.507246]
# step:15619 dis[loss:0.672257] adv[loss:1.181492]
# step:15620 dis[loss:0.679291] adv[loss:0.556399]
# step:15621 dis[loss:0.718084] adv[loss:1.141013]
# step:15622 dis[loss:0.678943] adv[loss:0.669242]
# step:15623 dis[loss:0.652577] adv[loss:0.919652]
# step:15624 dis[loss:0.634276] adv[loss:0.847844]
# step:15625 dis[loss:0.642202] adv[loss:0.770051]
# step:15626 dis[loss:0.633643] adv[loss:0.888957]
# step:15627 dis[loss:0.656962] adv[loss:0.749955]
# step:15628 dis[loss:0.616742] adv[loss:0.873848]
# step:15629 dis[loss:0.665788] adv[loss:0.772545]
# step:15630 dis[loss:0.613859] adv[loss:0.875199]
# step:15631 dis[loss:0.629706] adv[loss:0.781042]
# step:15632 dis[loss:0.652790] adv[loss:0.805657]
# step:15633 dis[loss:0.647723] adv[loss:0.706999]
# step:15634 dis[loss:0.664269] adv[loss:0.900616]
# step:15635 dis[loss:0.623943] adv[loss:0.635035]
# step:15636 dis[loss:0.668870] adv[loss:0.961477]
# step:15637 dis[loss:0.633826] adv[loss:0.678698]
# step:15638 dis[loss:0.658157] adv[loss:1.228932]
# step:15639 dis[loss:0.695287] adv[loss:0.606458]
# step:15640 dis[loss:0.686021] adv[loss:1.148132]
# step:15641 dis[loss:0.672811] adv[loss:0.687199]
# step:15642 dis[loss:0.664939] adv[loss:0.958210]
# step:15643 dis[loss:0.644693] adv[loss:0.743123]
# step:15644 dis[loss:0.647456] adv[loss:0.855526]
# step:15645 dis[loss:0.634335] adv[loss:0.814352]
# step:15646 dis[loss:0.652015] adv[loss:0.834768]
# step:15647 dis[loss:0.669663] adv[loss:0.857286]
# step:15648 dis[loss:0.620615] adv[loss:0.823684]
# step:15649 dis[loss:0.653563] adv[loss:0.784002]
# step:15650 dis[loss:0.647592] adv[loss:0.778303]
# step:15651 dis[loss:0.666581] adv[loss:0.760236]
# step:15652 dis[loss:0.619542] adv[loss:0.795075]
# step:15653 dis[loss:0.669234] adv[loss:0.916010]
# step:15654 dis[loss:0.668457] adv[loss:0.537056]
# step:15655 dis[loss:0.690652] adv[loss:1.022533]
# step:15656 dis[loss:0.664204] adv[loss:0.636899]
# step:15657 dis[loss:0.665511] adv[loss:1.101180]
# step:15658 dis[loss:0.646712] adv[loss:0.700613]
# step:15659 dis[loss:0.672661] adv[loss:1.061931]
# step:15660 dis[loss:0.660313] adv[loss:0.734892]
# step:15661 dis[loss:0.662229] adv[loss:1.029666]
# step:15662 dis[loss:0.648434] adv[loss:0.831753]
# step:15663 dis[loss:0.654731] adv[loss:0.894047]
# step:15664 dis[loss:0.664661] adv[loss:0.765803]
# step:15665 dis[loss:0.636241] adv[loss:0.906108]
# step:15666 dis[loss:0.600720] adv[loss:0.803845]
# step:15667 dis[loss:0.641572] adv[loss:1.010979]
# step:15668 dis[loss:0.695690] adv[loss:0.702254]
# step:15669 dis[loss:0.616626] adv[loss:0.977388]
# step:15670 dis[loss:0.613494] adv[loss:0.602658]
# step:15671 dis[loss:0.667934] adv[loss:1.046549]
# step:15672 dis[loss:0.661805] adv[loss:0.691600]
# step:15673 dis[loss:0.661577] adv[loss:0.900840]
# step:15674 dis[loss:0.633218] adv[loss:0.823040]
# step:15675 dis[loss:0.633027] adv[loss:0.818989]
# step:15676 dis[loss:0.625612] adv[loss:0.728860]
# step:15677 dis[loss:0.625100] adv[loss:1.001204]
# step:15678 dis[loss:0.677543] adv[loss:0.645471]
# step:15679 dis[loss:0.699452] adv[loss:1.043739]
# step:15680 dis[loss:0.687166] adv[loss:0.614462]
# step:15681 dis[loss:0.658056] adv[loss:1.093400]
# step:15682 dis[loss:0.668425] adv[loss:0.671547]
# step:15683 dis[loss:0.672988] adv[loss:0.986954]
# step:15684 dis[loss:0.668634] adv[loss:0.669754]
# step:15685 dis[loss:0.640434] adv[loss:1.042369]
# step:15686 dis[loss:0.696472] adv[loss:0.624993]
# step:15687 dis[loss:0.724761] adv[loss:0.986852]
# step:15688 dis[loss:0.653501] adv[loss:0.696922]
# step:15689 dis[loss:0.688271] adv[loss:0.942671]
# step:15690 dis[loss:0.628374] adv[loss:0.774479]
# step:15691 dis[loss:0.649277] adv[loss:0.830463]
# step:15692 dis[loss:0.636741] adv[loss:0.872915]
# step:15693 dis[loss:0.636510] adv[loss:0.798150]
# step:15694 dis[loss:0.672955] adv[loss:0.714494]
# step:15695 dis[loss:0.641616] adv[loss:0.908448]
# step:15696 dis[loss:0.641689] adv[loss:0.737820]
# step:15697 dis[loss:0.642112] adv[loss:0.970129]
# step:15698 dis[loss:0.656314] adv[loss:0.692126]
# step:15699 dis[loss:0.636749] adv[loss:0.971513]
# step:15700 dis[loss:0.635209] adv[loss:0.736300]
# step:15701 dis[loss:0.631833] adv[loss:0.989533]
# step:15702 dis[loss:0.657322] adv[loss:0.638404]
# step:15703 dis[loss:0.668462] adv[loss:1.003266]
# step:15704 dis[loss:0.667689] adv[loss:0.703985]
# step:15705 dis[loss:0.656833] adv[loss:0.871245]
# step:15706 dis[loss:0.641135] adv[loss:0.621953]
# step:15707 dis[loss:0.640487] adv[loss:1.172222]
# step:15708 dis[loss:0.708844] adv[loss:0.587453]
# step:15709 dis[loss:0.645979] adv[loss:1.061034]
# step:15710 dis[loss:0.678407] adv[loss:0.756824]
# step:15711 dis[loss:0.618070] adv[loss:0.883420]
# step:15712 dis[loss:0.667603] adv[loss:0.797421]
# step:15713 dis[loss:0.632091] adv[loss:0.898884]
# step:15714 dis[loss:0.631002] adv[loss:0.746288]
# step:15715 dis[loss:0.680962] adv[loss:0.913577]
# step:15716 dis[loss:0.704010] adv[loss:0.718769]
# step:15717 dis[loss:0.646384] adv[loss:1.092094]
# step:15718 dis[loss:0.717197] adv[loss:0.604125]
# step:15719 dis[loss:0.653390] adv[loss:1.258340]
# step:15720 dis[loss:0.702054] adv[loss:0.664639]
# step:15721 dis[loss:0.691495] adv[loss:0.988425]
# step:15722 dis[loss:0.655558] adv[loss:0.775726]
# step:15723 dis[loss:0.644509] adv[loss:0.989205]
# step:15724 dis[loss:0.669692] adv[loss:0.735972]
# step:15725 dis[loss:0.643144] adv[loss:1.051717]
# step:15726 dis[loss:0.639087] adv[loss:0.670155]
# step:15727 dis[loss:0.669062] adv[loss:0.913483]
# step:15728 dis[loss:0.675603] adv[loss:0.746960]
# step:15729 dis[loss:0.647337] adv[loss:0.884543]
# step:15730 dis[loss:0.644078] adv[loss:0.744910]
# step:15731 dis[loss:0.666759] adv[loss:0.935965]
# step:15732 dis[loss:0.644634] adv[loss:0.727392]
# step:15733 dis[loss:0.675310] adv[loss:1.021498]
# step:15734 dis[loss:0.672788] adv[loss:0.646641]
# step:15735 dis[loss:0.622381] adv[loss:1.048089]
# step:15736 dis[loss:0.661360] adv[loss:0.672658]
# step:15737 dis[loss:0.626096] adv[loss:1.052750]
# step:15738 dis[loss:0.703537] adv[loss:0.605239]
# step:15739 dis[loss:0.692223] adv[loss:1.085270]
# step:15740 dis[loss:0.694842] adv[loss:0.694219]
# step:15741 dis[loss:0.676389] adv[loss:0.944308]
# step:15742 dis[loss:0.685253] adv[loss:0.758958]
# step:15743 dis[loss:0.600880] adv[loss:0.847021]
# step:15744 dis[loss:0.625557] adv[loss:0.716240]
# step:15745 dis[loss:0.633442] adv[loss:0.820976]
# step:15746 dis[loss:0.637858] adv[loss:0.875680]
# step:15747 dis[loss:0.652048] adv[loss:0.918143]
# step:15748 dis[loss:0.610640] adv[loss:0.894558]
# step:15749 dis[loss:0.677981] adv[loss:0.874846]
# step:15750 dis[loss:0.644223] adv[loss:0.846807]
# step:15751 dis[loss:0.637129] adv[loss:0.770936]
# step:15752 dis[loss:0.653533] adv[loss:1.012011]
# step:15753 dis[loss:0.614827] adv[loss:0.783111]
# step:15754 dis[loss:0.618220] adv[loss:1.146456]
# step:15755 dis[loss:0.680785] adv[loss:0.522930]
# step:15756 dis[loss:0.703681] adv[loss:1.256574]
# step:15757 dis[loss:0.667786] adv[loss:0.572207]
# step:15758 dis[loss:0.660353] adv[loss:0.994486]
# step:15759 dis[loss:0.679704] adv[loss:0.660243]
# step:15760 dis[loss:0.650014] adv[loss:0.964268]
# step:15761 dis[loss:0.677946] adv[loss:0.709790]
# step:15762 dis[loss:0.638411] adv[loss:0.943191]
# step:15763 dis[loss:0.608629] adv[loss:0.745050]
# step:15764 dis[loss:0.633311] adv[loss:0.995142]
# step:15765 dis[loss:0.613912] adv[loss:0.665930]
# step:15766 dis[loss:0.693432] adv[loss:1.070173]
# step:15767 dis[loss:0.742996] adv[loss:0.675559]
# step:15768 dis[loss:0.672928] adv[loss:1.038744]
# step:15769 dis[loss:0.641697] adv[loss:0.709130]
# step:15770 dis[loss:0.631815] adv[loss:1.031009]
# step:15771 dis[loss:0.670249] adv[loss:0.726191]
# step:15772 dis[loss:0.612771] adv[loss:0.995302]
# step:15773 dis[loss:0.647527] adv[loss:0.676057]
# step:15774 dis[loss:0.662152] adv[loss:0.883164]
# step:15775 dis[loss:0.638540] adv[loss:0.798092]
# step:15776 dis[loss:0.635693] adv[loss:0.861143]
# step:15777 dis[loss:0.655960] adv[loss:0.747440]
# step:15778 dis[loss:0.652854] adv[loss:0.906869]
# step:15779 dis[loss:0.638840] adv[loss:0.821060]
# step:15780 dis[loss:0.631773] adv[loss:0.975683]
# step:15781 dis[loss:0.650365] adv[loss:0.822628]
# step:15782 dis[loss:0.632312] adv[loss:0.720713]
# ...
# step:19675 dis[loss:0.642080] adv[loss:0.813677]
# step:19676 dis[loss:0.615141] adv[loss:0.979267]
# step:19677 dis[loss:0.624529] adv[loss:0.854442]
# step:19678 dis[loss:0.676764] adv[loss:1.148605]
# step:19679 dis[loss:0.661472] adv[loss:0.598734]
# step:19680 dis[loss:0.679079] adv[loss:1.221965]
# step:19681 dis[loss:0.728453] adv[loss:0.650401]
# step:19682 dis[loss:0.671261] adv[loss:1.147589]
# step:19683 dis[loss:0.687314] adv[loss:0.717738]
# step:19684 dis[loss:0.655091] adv[loss:0.986080]
# step:19685 dis[loss:0.661071] adv[loss:0.815754]
# step:19686 dis[loss:0.603329] adv[loss:0.942494]
# step:19687 dis[loss:0.629829] adv[loss:0.719105]
# step:19688 dis[loss:0.634491] adv[loss:0.987020]
# step:19689 dis[loss:0.669257] adv[loss:0.675980]
# step:19690 dis[loss:0.685492] adv[loss:1.013362]
# step:19691 dis[loss:0.628651] adv[loss:0.760640]
# step:19692 dis[loss:0.636650] adv[loss:1.088067]
# step:19693 dis[loss:0.667997] adv[loss:0.686933]
# step:19694 dis[loss:0.644944] adv[loss:0.957136]
# step:19695 dis[loss:0.679121] adv[loss:0.853577]
# step:19696 dis[loss:0.661225] adv[loss:0.779628]
# step:19697 dis[loss:0.580406] adv[loss:0.829273]
# step:19698 dis[loss:0.615874] adv[loss:0.903255]
# step:19699 dis[loss:0.674187] adv[loss:0.840087]
# step:19700 dis[loss:0.676694] adv[loss:0.828065]
# step:19701 dis[loss:0.656079] adv[loss:0.866797]
# step:19702 dis[loss:0.612776] adv[loss:0.818943]
# step:19703 dis[loss:0.588473] adv[loss:0.835051]
# step:19704 dis[loss:0.630874] adv[loss:0.992780]
# step:19705 dis[loss:0.640401] adv[loss:0.968694]
# step:19706 dis[loss:0.655090] adv[loss:0.854819]
# step:19707 dis[loss:0.634103] adv[loss:0.900580]
# step:19708 dis[loss:0.598034] adv[loss:0.704345]
# step:19709 dis[loss:0.640967] adv[loss:1.069872]
# step:19710 dis[loss:0.639152] adv[loss:0.620448]
# step:19711 dis[loss:0.683627] adv[loss:1.238236]
# step:19712 dis[loss:0.657135] adv[loss:0.559103]
# step:19713 dis[loss:0.672313] adv[loss:1.206894]
# step:19714 dis[loss:0.681554] adv[loss:0.711146]
# step:19715 dis[loss:0.639843] adv[loss:0.921021]
# step:19716 dis[loss:0.628367] adv[loss:0.699757]
# step:19717 dis[loss:0.656145] adv[loss:0.931090]
# step:19718 dis[loss:0.657446] adv[loss:0.723783]
# step:19719 dis[loss:0.637338] adv[loss:0.991125]
# step:19720 dis[loss:0.630288] adv[loss:0.794776]
# step:19721 dis[loss:0.681197] adv[loss:1.040055]
# step:19722 dis[loss:0.641756] adv[loss:0.738534]
# step:19723 dis[loss:0.670102] adv[loss:0.838289]
# step:19724 dis[loss:0.609974] adv[loss:0.687198]
# step:19725 dis[loss:0.651259] adv[loss:0.944422]
# step:19726 dis[loss:0.631640] adv[loss:0.763203]
# step:19727 dis[loss:0.648131] adv[loss:1.047188]
# step:19728 dis[loss:0.646730] adv[loss:0.845433]
# step:19729 dis[loss:0.639218] adv[loss:0.919110]
# step:19730 dis[loss:0.616837] adv[loss:0.866929]
# step:19731 dis[loss:0.638067] adv[loss:0.718018]
# step:19732 dis[loss:0.671364] adv[loss:1.120390]
# step:19733 dis[loss:0.649136] adv[loss:0.607179]
# step:19734 dis[loss:0.674631] adv[loss:1.245952]
# step:19735 dis[loss:0.715516] adv[loss:0.611426]
# step:19736 dis[loss:0.655181] adv[loss:1.014111]
# step:19737 dis[loss:0.705464] adv[loss:0.665366]
# step:19738 dis[loss:0.623824] adv[loss:1.033818]
# step:19739 dis[loss:0.635290] adv[loss:0.703721]
# step:19740 dis[loss:0.622425] adv[loss:0.944502]
# step:19741 dis[loss:0.614998] adv[loss:0.766814]
# step:19742 dis[loss:0.667625] adv[loss:0.749903]
# step:19743 dis[loss:0.693865] adv[loss:0.880392]
# step:19744 dis[loss:0.670168] adv[loss:1.105233]
# step:19745 dis[loss:0.666834] adv[loss:0.674842]
# step:19746 dis[loss:0.650924] adv[loss:1.076700]
# step:19747 dis[loss:0.673861] adv[loss:0.605673]
# step:19748 dis[loss:0.650846] adv[loss:1.080099]
# step:19749 dis[loss:0.628174] adv[loss:0.758656]
# step:19750 dis[loss:0.581987] adv[loss:0.962432]
# step:19751 dis[loss:0.643342] adv[loss:0.864261]
# step:19752 dis[loss:0.656641] adv[loss:0.772425]
# step:19753 dis[loss:0.641309] adv[loss:0.841486]
# step:19754 dis[loss:0.697575] adv[loss:0.846386]
# step:19755 dis[loss:0.625382] adv[loss:0.822423]
# step:19756 dis[loss:0.616167] adv[loss:0.852670]
# step:19757 dis[loss:0.628362] adv[loss:0.868958]
# step:19758 dis[loss:0.639677] adv[loss:0.753897]
# step:19759 dis[loss:0.626065] adv[loss:0.914670]
# step:19760 dis[loss:0.666593] adv[loss:0.822601]
# step:19761 dis[loss:0.644636] adv[loss:0.974483]
# step:19762 dis[loss:0.575510] adv[loss:0.675962]
# step:19763 dis[loss:0.596818] adv[loss:1.297021]
# step:19764 dis[loss:0.679435] adv[loss:0.587099]
# step:19765 dis[loss:0.669578] adv[loss:1.208249]
# step:19766 dis[loss:0.679445] adv[loss:0.623851]
# step:19767 dis[loss:0.645572] adv[loss:1.004717]
# step:19768 dis[loss:0.627029] adv[loss:0.666018]
# step:19769 dis[loss:0.635958] adv[loss:1.087737]
# step:19770 dis[loss:0.689633] adv[loss:0.657200]
# step:19771 dis[loss:0.658069] adv[loss:1.024905]
# step:19772 dis[loss:0.676686] adv[loss:0.810498]
# step:19773 dis[loss:0.674848] adv[loss:0.986306]
# step:19774 dis[loss:0.655414] adv[loss:0.806571]
# step:19775 dis[loss:0.712615] adv[loss:0.839588]
# step:19776 dis[loss:0.611929] adv[loss:0.812845]
# step:19777 dis[loss:0.637480] adv[loss:0.822060]
# step:19778 dis[loss:0.619697] adv[loss:0.757982]
# step:19779 dis[loss:0.677053] adv[loss:0.797677]
# step:19780 dis[loss:0.659043] adv[loss:0.870578]
# step:19781 dis[loss:0.689231] adv[loss:0.657349]
# step:19782 dis[loss:0.656950] adv[loss:0.866953]
# step:19783 dis[loss:0.646326] adv[loss:0.699997]
# step:19784 dis[loss:0.590225] adv[loss:0.915218]
# step:19785 dis[loss:0.596710] adv[loss:0.737814]
# step:19786 dis[loss:0.672718] adv[loss:0.863246]
# step:19787 dis[loss:0.632036] adv[loss:0.629380]
# step:19788 dis[loss:0.635226] adv[loss:1.315149]
# step:19789 dis[loss:0.691974] adv[loss:0.580412]
# step:19790 dis[loss:0.673918] adv[loss:0.983595]
# step:19791 dis[loss:0.686997] adv[loss:0.611525]
# step:19792 dis[loss:0.692241] adv[loss:1.003875]
# step:19793 dis[loss:0.672911] adv[loss:0.704449]
# step:19794 dis[loss:0.629761] adv[loss:0.986777]
# step:19795 dis[loss:0.644015] adv[loss:0.641870]
# step:19796 dis[loss:0.675085] adv[loss:0.962532]
# step:19797 dis[loss:0.654322] adv[loss:0.821502]
# step:19798 dis[loss:0.627817] adv[loss:1.109022]
# step:19799 dis[loss:0.656151] adv[loss:0.760945]
# step:19800 dis[loss:0.610256] adv[loss:0.903263]
# step:19801 dis[loss:0.608534] adv[loss:0.767563]
# step:19802 dis[loss:0.619452] adv[loss:1.031690]
# step:19803 dis[loss:0.690686] adv[loss:0.726428]
# step:19804 dis[loss:0.654393] adv[loss:0.816940]
# step:19805 dis[loss:0.634034] adv[loss:0.832381]
# step:19806 dis[loss:0.653128] adv[loss:0.876667]
# step:19807 dis[loss:0.646648] adv[loss:0.823874]
# step:19808 dis[loss:0.628350] adv[loss:0.822823]
# step:19809 dis[loss:0.645626] adv[loss:0.804856]
# step:19810 dis[loss:0.715898] adv[loss:1.012989]
# step:19811 dis[loss:0.647511] adv[loss:0.655322]
# step:19812 dis[loss:0.649466] adv[loss:1.133453]
# step:19813 dis[loss:0.646260] adv[loss:0.581972]
# step:19814 dis[loss:0.664311] adv[loss:1.029290]
# step:19815 dis[loss:0.652674] adv[loss:0.773003]
# step:19816 dis[loss:0.691964] adv[loss:0.962898]
# step:19817 dis[loss:0.613102] adv[loss:0.649582]
# step:19818 dis[loss:0.676512] adv[loss:1.047921]
# step:19819 dis[loss:0.622354] adv[loss:0.650760]
# step:19820 dis[loss:0.817274] adv[loss:1.055655]
# step:19821 dis[loss:0.705308] adv[loss:0.741086]
# step:19822 dis[loss:0.678194] adv[loss:1.006605]
# step:19823 dis[loss:0.660468] adv[loss:0.815377]
# step:19824 dis[loss:0.634580] adv[loss:0.790811]
# step:19825 dis[loss:0.659080] adv[loss:0.874783]
# step:19826 dis[loss:0.636778] adv[loss:0.955260]
# step:19827 dis[loss:0.642823] adv[loss:0.846330]
# step:19828 dis[loss:0.657554] adv[loss:0.982913]
# step:19829 dis[loss:0.669754] adv[loss:0.655947]
# step:19830 dis[loss:0.661413] adv[loss:1.001316]
# step:19831 dis[loss:0.627412] adv[loss:0.706151]
# step:19832 dis[loss:0.636430] adv[loss:0.989056]
# step:19833 dis[loss:0.636126] adv[loss:0.673079]
# step:19834 dis[loss:0.664397] adv[loss:1.053050]
# step:19835 dis[loss:0.628878] adv[loss:0.653118]
# step:19836 dis[loss:0.643137] adv[loss:1.203941]
# step:19837 dis[loss:0.749866] adv[loss:0.593053]
# step:19838 dis[loss:0.657621] adv[loss:1.091970]
# step:19839 dis[loss:0.750783] adv[loss:0.801503]
# step:19840 dis[loss:0.666406] adv[loss:0.905528]
# step:19841 dis[loss:0.612804] adv[loss:0.971224]
# step:19842 dis[loss:0.670618] adv[loss:0.913317]
# step:19843 dis[loss:0.612913] adv[loss:0.729377]
# step:19844 dis[loss:0.599781] adv[loss:0.872139]
# step:19845 dis[loss:0.622405] adv[loss:0.724706]
# step:19846 dis[loss:0.713417] adv[loss:0.925259]
# step:19847 dis[loss:0.644642] adv[loss:0.704323]
# step:19848 dis[loss:0.651244] adv[loss:1.084233]
# step:19849 dis[loss:0.673432] adv[loss:0.625042]
# step:19850 dis[loss:0.629927] adv[loss:1.127421]
# step:19851 dis[loss:0.615159] adv[loss:0.748327]
# step:19852 dis[loss:0.631795] adv[loss:1.052906]
# step:19853 dis[loss:0.647699] adv[loss:0.671704]
# step:19854 dis[loss:0.697184] adv[loss:1.009944]
# step:19855 dis[loss:0.637169] adv[loss:0.687451]
# step:19856 dis[loss:0.665789] adv[loss:1.173225]
# step:19857 dis[loss:0.685036] adv[loss:0.684646]
# step:19858 dis[loss:0.666766] adv[loss:0.944337]
# step:19859 dis[loss:0.613313] adv[loss:0.770209]
# step:19860 dis[loss:0.630834] adv[loss:0.782874]
# step:19861 dis[loss:0.616951] adv[loss:0.885802]
# step:19862 dis[loss:0.639305] adv[loss:0.736178]
# step:19863 dis[loss:0.656078] adv[loss:0.998352]
# step:19864 dis[loss:0.646016] adv[loss:0.714437]
# step:19865 dis[loss:0.627659] adv[loss:1.142727]
# step:19866 dis[loss:0.680884] adv[loss:0.571081]
# step:19867 dis[loss:0.685040] adv[loss:1.222035]
# step:19868 dis[loss:0.682736] adv[loss:0.773577]
# step:19869 dis[loss:0.615829] adv[loss:0.932514]
# step:19870 dis[loss:0.606076] adv[loss:0.767958]
# step:19871 dis[loss:0.615326] adv[loss:0.911272]
# step:19872 dis[loss:0.653255] adv[loss:0.625730]
# step:19873 dis[loss:0.766176] adv[loss:1.094244]
# step:19874 dis[loss:0.653302] adv[loss:0.701132]
# step:19875 dis[loss:0.736215] adv[loss:1.000697]
# step:19876 dis[loss:0.672081] adv[loss:0.660192]
# step:19877 dis[loss:0.674796] adv[loss:0.974465]
# step:19878 dis[loss:0.619883] adv[loss:0.827459]
# step:19879 dis[loss:0.603331] adv[loss:0.745058]
# step:19880 dis[loss:0.599840] adv[loss:0.874101]
# step:19881 dis[loss:0.701319] adv[loss:0.701462]
# step:19882 dis[loss:0.621123] adv[loss:0.900047]
# step:19883 dis[loss:0.624916] adv[loss:0.817892]
# step:19884 dis[loss:0.635139] adv[loss:0.865372]
# step:19885 dis[loss:0.602442] adv[loss:0.735373]
# step:19886 dis[loss:0.621882] adv[loss:1.025853]
# step:19887 dis[loss:0.647206] adv[loss:0.868550]
# step:19888 dis[loss:0.628885] adv[loss:0.985655]
# step:19889 dis[loss:0.598354] adv[loss:0.675384]
# step:19890 dis[loss:0.676609] adv[loss:1.164377]
# step:19891 dis[loss:0.689302] adv[loss:0.581124]
# step:19892 dis[loss:0.682482] adv[loss:1.229845]
# step:19893 dis[loss:0.653617] adv[loss:0.667055]
# step:19894 dis[loss:0.668725] adv[loss:0.927646]
# step:19895 dis[loss:0.616784] adv[loss:0.756974]
# step:19896 dis[loss:0.628211] adv[loss:0.929909]
# step:19897 dis[loss:0.618912] adv[loss:0.932377]
# step:19898 dis[loss:0.629479] adv[loss:0.872246]
# step:19899 dis[loss:0.615543] adv[loss:0.872540]
# step:19900 dis[loss:0.691728] adv[loss:0.874053]
# step:19901 dis[loss:0.646110] adv[loss:0.796974]
# step:19902 dis[loss:0.667477] adv[loss:0.809534]
# step:19903 dis[loss:0.588129] adv[loss:0.813690]
# step:19904 dis[loss:0.664956] adv[loss:0.933437]
# step:19905 dis[loss:0.708969] adv[loss:0.754058]
# step:19906 dis[loss:0.712350] adv[loss:0.670482]
# step:19907 dis[loss:0.661776] adv[loss:1.046685]
# step:19908 dis[loss:0.635262] adv[loss:0.586102]
# step:19909 dis[loss:0.682641] adv[loss:1.163414]
# step:19910 dis[loss:0.684064] adv[loss:0.637128]
# step:19911 dis[loss:0.623545] adv[loss:0.998881]
# step:19912 dis[loss:0.686291] adv[loss:0.555089]
# step:19913 dis[loss:0.673335] adv[loss:1.076026]
# step:19914 dis[loss:0.626000] adv[loss:0.713722]
# step:19915 dis[loss:0.674216] adv[loss:0.927190]
# step:19916 dis[loss:0.644578] adv[loss:0.724373]
# step:19917 dis[loss:0.695119] adv[loss:0.949831]
# step:19918 dis[loss:0.648368] adv[loss:0.795345]
# step:19919 dis[loss:0.639124] adv[loss:0.929244]
# step:19920 dis[loss:0.642524] adv[loss:0.744602]
# step:19921 dis[loss:0.630856] adv[loss:0.879163]
# step:19922 dis[loss:0.662929] adv[loss:0.827904]
# step:19923 dis[loss:0.708925] adv[loss:0.870235]
# step:19924 dis[loss:0.651492] adv[loss:0.952302]
# step:19925 dis[loss:0.618540] adv[loss:0.961745]
# step:19926 dis[loss:0.674764] adv[loss:0.665878]
# step:19927 dis[loss:0.625834] adv[loss:1.082544]
# step:19928 dis[loss:0.633360] adv[loss:0.597183]
# step:19929 dis[loss:0.671731] adv[loss:1.036937]
# step:19930 dis[loss:0.626444] adv[loss:0.811279]
# step:19931 dis[loss:0.693467] adv[loss:0.924095]
# step:19932 dis[loss:0.656506] adv[loss:0.719747]
# step:19933 dis[loss:0.668113] adv[loss:1.013927]
# step:19934 dis[loss:0.637249] adv[loss:0.617418]
# step:19935 dis[loss:0.642737] adv[loss:1.026724]
# step:19936 dis[loss:0.612637] adv[loss:0.680797]
# step:19937 dis[loss:0.658662] adv[loss:1.053541]
# step:19938 dis[loss:0.638454] adv[loss:0.706200]
# step:19939 dis[loss:0.691035] adv[loss:1.010313]
# step:19940 dis[loss:0.660221] adv[loss:0.764864]
# step:19941 dis[loss:0.652432] adv[loss:0.868010]
# step:19942 dis[loss:0.666153] adv[loss:0.763355]
# step:19943 dis[loss:0.651519] adv[loss:1.034262]
# step:19944 dis[loss:0.658329] adv[loss:0.725439]
# step:19945 dis[loss:0.707033] adv[loss:0.965225]
# step:19946 dis[loss:0.588345] adv[loss:0.752500]
# step:19947 dis[loss:0.696738] adv[loss:1.106038]
# step:19948 dis[loss:0.618118] adv[loss:0.621877]
# step:19949 dis[loss:0.683702] adv[loss:1.182686]
# step:19950 dis[loss:0.648679] adv[loss:0.600320]
# step:19951 dis[loss:0.701054] adv[loss:1.074947]
# step:19952 dis[loss:0.638852] adv[loss:0.775166]
# step:19953 dis[loss:0.683665] adv[loss:0.752972]
# step:19954 dis[loss:0.668146] adv[loss:0.714393]
# step:19955 dis[loss:0.638856] adv[loss:0.945920]
# step:19956 dis[loss:0.629434] adv[loss:0.825109]
# step:19957 dis[loss:0.673305] adv[loss:0.907958]
# step:19958 dis[loss:0.601367] adv[loss:0.788751]
# step:19959 dis[loss:0.612795] adv[loss:0.947603]
# step:19960 dis[loss:0.630660] adv[loss:0.604235]
# step:19961 dis[loss:0.625733] adv[loss:1.070356]
# step:19962 dis[loss:0.674627] adv[loss:0.569800]
# step:19963 dis[loss:0.694660] adv[loss:0.900867]
# step:19964 dis[loss:0.679182] adv[loss:0.677370]
# step:19965 dis[loss:0.628979] adv[loss:1.056228]
# step:19966 dis[loss:0.633440] adv[loss:0.666361]
# step:19967 dis[loss:0.646245] adv[loss:1.013266]
# step:19968 dis[loss:0.617077] adv[loss:0.803402]
# step:19969 dis[loss:0.682329] adv[loss:0.937219]
# step:19970 dis[loss:0.682849] adv[loss:0.667046]
# step:19971 dis[loss:0.602443] adv[loss:0.949463]
# step:19972 dis[loss:0.655910] adv[loss:0.702370]
# step:19973 dis[loss:0.658817] adv[loss:0.935842]
# step:19974 dis[loss:0.665950] adv[loss:0.602890]
# step:19975 dis[loss:0.645151] adv[loss:0.921155]
# step:19976 dis[loss:0.644572] adv[loss:0.757625]
# step:19977 dis[loss:0.640973] adv[loss:0.934576]
# step:19978 dis[loss:0.663592] adv[loss:0.741072]
# step:19979 dis[loss:0.680980] adv[loss:0.947926]
# step:19980 dis[loss:0.637024] adv[loss:0.802103]
# step:19981 dis[loss:0.635406] adv[loss:0.933022]
# step:19982 dis[loss:0.630535] adv[loss:0.832026]
# step:19983 dis[loss:0.628335] adv[loss:1.197202]
# step:19984 dis[loss:0.755071] adv[loss:0.701347]
# step:19985 dis[loss:0.677116] adv[loss:1.155676]
# step:19986 dis[loss:0.691126] adv[loss:0.752824]
# step:19987 dis[loss:0.636123] adv[loss:1.003277]
# step:19988 dis[loss:0.636194] adv[loss:0.810032]
# step:19989 dis[loss:0.629024] adv[loss:0.742250]
# step:19990 dis[loss:0.669667] adv[loss:0.928117]
# step:19991 dis[loss:0.635825] adv[loss:0.800092]
# step:19992 dis[loss:0.601352] adv[loss:0.862665]
# step:19993 dis[loss:0.643419] adv[loss:0.992568]
# step:19994 dis[loss:0.694307] adv[loss:0.714060]
# step:19995 dis[loss:0.606775] adv[loss:0.960110]
# step:19996 dis[loss:0.664834] adv[loss:0.739646]
# step:19997 dis[loss:0.667601] adv[loss:1.165453]
# step:19998 dis[loss:0.660199] adv[loss:0.560898]
# step:19999 dis[loss:0.638278] adv[loss:1.094076]
# step:20000 dis[loss:0.731501] adv[loss:0.571468]
